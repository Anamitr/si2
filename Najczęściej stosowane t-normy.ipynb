# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
def plotNorm(fun, ax):
    X = np.arange(0, 1.01, 0.01)
    Y = np.arange(0, 1.01, 0.01)
    Z = np.array([np.array([fun(x,y) for x in X]) for y in Y] )
    X, Y = np.meshgrid(X, Y)

    surf = ax.plot_surface(X, Y, Z, cmap=cm.jet, antialiased=True)

    ax.set_zlim(-0.1, 1.1)
    ax.zaxis.set_major_locator(LinearLocator(11))
    ax.zaxis.set_major_formatter(FormatStrFormatter('%.1f'))
    ax.view_init(elev=20, azim=250)

# %%
def plotNorms(fun1, fun2):
    fig = plt.figure(figsize=(20, 10))
    ax1 = fig.add_subplot(121,projection='3d')
    ax2 = fig.add_subplot(122,projection='3d')
    
    plotNorm(fun1, ax1)
    plotNorm(fun2, ax2)
   
    plt.show()

# %% [markdown]
# <H1>Zadeh t-norm</H1>

# %%
def zadeh_t(x,y):
    return min(x,y)
def zadeh_s(x,y):
    return max(x,y)
plotNorms(zadeh_t,zadeh_s)

# %% [markdown]
# <H1>Algebraic t-norm</H1>

# %%
def algebraic_t(x,y):
    return x*y
def probabilistic_s(x,y):
    return x+y-x*y
plotNorms(algebraic_t,probabilistic_s)

# %% [markdown]
# <H1>Łukasiewicz t-norm</H1>

# %%
def lukasiewicz_t(x,y):
    return max(x+y-1.0,0)
def lukasiewicz_s(x,y):
    return min(x+y,1)
plotNorms(lukasiewicz_t,lukasiewicz_s)

# %% [markdown]
# <H1>Fodor t-norm</H1>

# %%
# %matplotlib qt
def fodor_t(x,y):
    if x+y>1:
        return min(x,y)
    else:
        return 0
def fodor_s(x,y):
    if x+y<1:
        return max(x,y)
    else:
        return 1
plotNorms(fodor_t,fodor_s)

# %% [markdown]
# <H1>Drastic t-norm</H1>

# %%
def drastic_t(x,y):
    if x == 1:
        return y
    elif y == 1:
        return x
    else:
        return 0
def drastic_s(x,y):
    pass
plotNorms(drastic_t,drastic_s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-b20cc00bc7c4> in <module>
#       8 def drastic_s(x,y):
#       9     pass
# ---> 10 plotNorms(drastic_t,drastic_s)
#
# <ipython-input-3-dec5b46ec31e> in plotNorms(fun1, fun2)
#       5
#       6     plotNorm(fun1, ax1)
# ----> 7     plotNorm(fun2, ax2)
#       8
#       9     plt.show()
#
# <ipython-input-2-578878dfe12d> in plotNorm(fun, ax)
#       5     X, Y = np.meshgrid(X, Y)
#       6
# ----> 7     surf = ax.plot_surface(X, Y, Z, cmap=cm.jet, antialiased=True)
#       8
#       9     ax.set_zlim(-0.1, 1.1)
#
# C:\Programy\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1605         if Z.ndim != 2:
#    1606             raise ValueError("Argument Z must be 2-dimensional.")
# -> 1607         if np.any(np.isnan(Z)):
#    1608             cbook._warn_external(
#    1609                 "Z contains NaN values. This may result in rendering "
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# <H1>Einstein t-norm</H1>

# %% [markdown]
# \begin{equation*}
# E(x,y)=\frac{xy}{2-(x+y-xy)}     \quad\quad\quad\quad     E'(x,y)=\frac{x+y}{1+xy}
# \end{equation*}

# %%
# %matplotlib qt
def einstein_t(x,y):
    return ((x*y) / (2 - (x + y - x*y)))
def einstein_s(x,y):
    return ((x + y) / (1 + x*y))
plotNorms(einstein_t,einstein_s)
